# %%
# Intialization
import os
import sys

os.environ["SPARK_HOME"] = "/home/talentum/spark"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
# In below two lines, use /usr/bin/python2.7 if you want to use Python 2
os.environ["PYSPARK_PYTHON"] = "/usr/bin/python3.6" 
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/bin/python3"
sys.path.insert(0, os.environ["PYLIB"] +"/py4j-0.10.7-src.zip")
sys.path.insert(0, os.environ["PYLIB"] +"/pyspark.zip")

# NOTE: Whichever package you want mention here.
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0 pyspark-shell' 
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.3 pyspark-shell'
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'

# %%
#Entrypoint 2.x
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark SQL basic example").enableHiveSupport().getOrCreate()

# On yarn:
# spark = SparkSession.builder.appName("Spark SQL basic example").enableHiveSupport().master("yarn").getOrCreate()
# specify .master("yarn")

sc = spark.sparkContext

# %%
item_props_df = spark.read \
    .option("header", "true") \
    .csv("file:///home/talentum/test-jupyter/ecommerce-clickstream-etl/data/raw/item_properties*.csv")

item_props_df.printSchema()
item_props_df.show(5)
# Out:
# root
#  |-- timestamp: string (nullable = true)
#  |-- itemid: string (nullable = true)
#  |-- property: string (nullable = true)
#  |-- value: string (nullable = true)
#
# +-------------+------+----------+--------------------+
# |    timestamp|itemid|  property|               value|
# +-------------+------+----------+--------------------+
# |1435460400000|460429|categoryid|                1338|
# |1441508400000|206783|       888|1116713 960601 n2...|
# |1439089200000|395014|       400|n552.000 639502 n...|
# |1431226800000| 59481|       790|          n15360.000|
# |1431831600000|156781|       917|              828513|
# +-------------+------+----------+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import col, row_number

window_spec = Window \
    .partitionBy("itemid", "property") \
    .orderBy(col("timestamp").desc())

latest_item_props_df = item_props_df \
    .withColumn("rn", row_number().over(window_spec)) \
    .filter(col("rn") == 1) \
    .drop("rn")

# %%
dim_items_df = latest_item_props_df \
    .groupBy("itemid") \
    .pivot("property") \
    .agg({"value": "first"})

dim_items_df.printSchema()
# Out:
# root
#  |-- itemid: string (nullable = true)
#  |-- 0: string (nullable = true)
#  |-- 1: string (nullable = true)
#  |-- 10: string (nullable = true)
#  |-- 100: string (nullable = true)
#  |-- 1000: string (nullable = true)
#  |-- 1001: string (nullable = true)
#  |-- 1002: string (nullable = true)
#  |-- 1003: string (nullable = true)
#  |-- 1004: string (nullable = true)
#  |-- 1005: string (nullable = true)
#  |-- 1006: string (nullable = true)
#  |-- 1007: string (nullable = true)
#  |-- 1008: string (nullable = true)
#  |-- 1009: string (nullable = true)
#  |-- 101: string (nullable = true)
#  |-- 1010: string (nullable = true)
#  |-- 1011: string (nullable = true)
#  |-- 1012: string (nullable = true)
#  |-- 1013: string (nullable = true)
#  |-- 1014: string (nullable = true)
#  |-- 1015: string (nullable = true)
#  |-- 1016: string (nullable = true)
#  |-- 1017: string (nullable = true)
#  |-- 1018: string (nullable = true)
#  |-- 1019: string (nullable = true)
#  |-- 102: string (nullable = true)
#  |-- 1020: string (nullable = true)
#  |-- 1021: string (nullable = true)
#  |-- 1022: string (nullable = true)
#  |-- 1023: string (nullable = true)
#  |-- 1024: string (nullable = true)
#  |-- 1025: string (nullable = true)
#  |-- 1026: string (nullable = true)
#  |-- 1027: string (nullable = true)
#  |-- 1028: string (nullable = true)
#  |-- 1029: string (nullable = true)
#  |-- 103: string (nullable = true)
#  |-- 1030: string (nullable = true)
#  |-- 1031: string (nullable = true)
#  |-- 1032: string (nullable = true)
#  |-- 1033: string (nullable = true)
#  |-- 1034: string (nullable = true)
#  |-- 1035: string (nullable = true)
#  |-- 1036: string (nullable = true)
#  |-- 1037: string (nullable = true)
#  |-- 1038: string (nullable = true)
#  |-- 1039: string (nullable = true)
#  |-- 104: string (nullable = true)
#  |-- 1040: string (nullable = true)
#  |-- 1041: string (nullable = true)
#  |-- 1042: string (nullable = true)
#  |-- 1043: string (nullable = true)
#  |-- 1044: string (nullable = true)
#  |-- 1045: string (nullable = true)
#  |-- 1046: string (nullable = true)
#  |-- 1047: string (nullable = true)
#  |-- 1048: string (nullable = true)
#  |-- 1049: string (nullable = true)
#  |-- 105: string (nullable = true)
#  |-- 1050: string (nullable = true)
#  |-- 1051: string (nullable = true)
#  |-- 1052: string (nullable = true)
#  |-- 1053: string (nullable = true)
#  |-- 1054: string (nullable = true)
#  |-- 1055: string (nullable = true)
#  |-- 1056: string (nullable = true)
#  |-- 1057: string (nullable = true)
#  |-- 1058: string (nullable = true)
#  |-- 1059: string (nullable = true)
#  |-- 106: string (nullable = true)
#  |-- 1060: string (nullable = true)
#  |-- 1061: string (nullable = true)
#  |-- 1062: string (nullable = true)
#  |-- 1063: string (nullable = true)
#  |-- 1064: string (nullable = true)
#  |-- 1065: string (nullable = true)
#  |-- 1066: string (nullable = true)
#  |-- 1067: string (nullable = true)
#  |-- 1068: string (nullable = true)
#  |-- 1069: string (nullable = true)
#  |-- 107: string (nullable = true)
#  |-- 1070: string (nullable = true)
#  |-- 1071: string (nullable = true)
#  |-- 1072: string (nullable = true)
#  |-- 1073: string (nullable = true)
#  |-- 1074: string (nullable = true)
#  |-- 1075: string (nullable = true)
#  |-- 1076: string (nullable = true)
#  |-- 1077: string (nullable = true)
#  |-- 1078: string (nullable = true)
#  |-- 1079: string (nullable = true)
#  |-- 108: string (nullable = true)
#  |-- 1080: string (nullable = true)
#  |-- 1081: string (nullable = true)
#  |-- 1082: string (nullable = true)
#  |-- 1083: string (nullable = true)
#  |-- 1084: string (nullable = true)
#  |-- 1085: string (nullable = true)
#  |-- 1086: string (nullable = true)
#  |-- 1087: string (nullable = true)
#  |-- 1088: string (nullable = true)
#  |-- 1089: string (nullable = true)
#  |-- 109: string (nullable = true)
#  |-- 1090: string (nullable = true)
#  |-- 1091: string (nullable = true)
#  |-- 1092: string (nullable = true)
#  |-- 1093: string (nullable = true)
#  |-- 1094: string (nullable = true)
#  |-- 1095: string (nullable = true)
#  |-- 1096: string (nullable = true)
#  |-- 1097: string (nullable = true)
#  |-- 1098: string (nullable = true)
#  |-- 1099: string (nullable = true)
#  |-- 11: string (nullable = true)
#  |-- 110: string (nullable = true)
#  |-- 1100: string (nullable = true)
#  |-- 1101: string (nullable = true)
#  |-- 1102: string (nullable = true)
#  |-- 1103: string (nullable = true)
#  |-- 1104: string (nullable = true)
#  |-- 111: string (nullable = true)
#  |-- 112: string (nullable = true)
#  |-- 113: string (nullable = true)
#  |-- 114: string (nullable = true)
#  |-- 115: string (nullable = true)
#  |-- 116: string (nullable = true)
#  |-- 117: string (nullable = true)
#  |-- 118: string (nullable = true)
#  |-- 119: string (nullable = true)
#  |-- 12: string (nullable = true)
#  |-- 120: string (nullable = true)
#  |-- 121: string (nullable = true)
#  |-- 122: string (nullable = true)
#  |-- 123: string (nullable = true)
#  |-- 124: string (nullable = true)
#  |-- 125: string (nullable = true)
#  |-- 126: string (nullable = true)
#  |-- 127: string (nullable = true)
#  |-- 128: string (nullable = true)
#  |-- 129: string (nullable = true)
#  |-- 13: string (nullable = true)
#  |-- 130: string (nullable = true)
#  |-- 131: string (nullable = true)
#  |-- 132: string (nullable = true)
#  |-- 133: string (nullable = true)
#  |-- 134: string (nullable = true)
#  |-- 135: string (nullable = true)
#  |-- 136: string (nullable = true)
#  |-- 137: string (nullable = true)
#  |-- 138: string (nullable = true)
#  |-- 139: string (nullable = true)
#  |-- 14: string (nullable = true)
#  |-- 140: string (nullable = true)
#  |-- 141: string (nullable = true)
#  |-- 142: string (nullable = true)
#  |-- 143: string (nullable = true)
#  |-- 144: string (nullable = true)
#  |-- 145: string (nullable = true)
#  |-- 146: string (nullable = true)
#  |-- 147: string (nullable = true)
#  |-- 148: string (nullable = true)
#  |-- 149: string (nullable = true)
#  |-- 15: string (nullable = true)
#  |-- 150: string (nullable = true)
#  |-- 151: string (nullable = true)
#  |-- 152: string (nullable = true)
#  |-- 153: string (nullable = true)
#  |-- 154: string (nullable = true)
#  |-- 155: string (nullable = true)
#  |-- 156: string (nullable = true)
#  |-- 157: string (nullable = true)
#  |-- 158: string (nullable = true)
#  |-- 159: string (nullable = true)
#  |-- 16: string (nullable = true)
#  |-- 160: string (nullable = true)
#  |-- 161: string (nullable = true)
#  |-- 162: string (nullable = true)
#  |-- 163: string (nullable = true)
#  |-- 164: string (nullable = true)
#  |-- 165: string (nullable = true)
#  |-- 166: string (nullable = true)
#  |-- 167: string (nullable = true)
#  |-- 168: string (nullable = true)
#  |-- 169: string (nullable = true)
#  |-- 17: string (nullable = true)
#  |-- 170: string (nullable = true)
#  |-- 171: string (nullable = true)
#  |-- 172: string (nullable = true)
#  |-- 173: string (nullable = true)
#  |-- 174: string (nullable = true)
#  |-- 175: string (nullable = true)
#  |-- 176: string (nullable = true)
#  |-- 177: string (nullable = true)
#  |-- 178: string (nullable = true)
#  |-- 179: string (nullable = true)
#  |-- 18: string (nullable = true)
#  |-- 180: string (nullable = true)
#  |-- 181: string (nullable = true)
#  |-- 182: string (nullable = true)
#  |-- 183: string (nullable = true)
#  |-- 184: string (nullable = true)
#  |-- 185: string (nullable = true)
#  |-- 186: string (nullable = true)
#  |-- 187: string (nullable = true)
#  |-- 188: string (nullable = true)
#  |-- 189: string (nullable = true)
#  |-- 19: string (nullable = true)
#  |-- 190: string (nullable = true)
#  |-- 191: string (nullable = true)
#  |-- 192: string (nullable = true)
#  |-- 193: string (nullable = true)
#  |-- 194: string (nullable = true)
#  |-- 195: string (nullable = true)
#  |-- 196: string (nullable = true)
#  |-- 197: string (nullable = true)
#  |-- 198: string (nullable = true)
#  |-- 199: string (nullable = true)
#  |-- 2: string (nullable = true)
#  |-- 20: string (nullable = true)
#  |-- 200: string (nullable = true)
#  |-- 201: string (nullable = true)
#  |-- 202: string (nullable = true)
#  |-- 203: string (nullable = true)
#  |-- 204: string (nullable = true)
#  |-- 205: string (nullable = true)
#  |-- 206: string (nullable = true)
#  |-- 207: string (nullable = true)
#  |-- 208: string (nullable = true)
#  |-- 209: string (nullable = true)
#  |-- 21: string (nullable = true)
#  |-- 210: string (nullable = true)
#  |-- 211: string (nullable = true)
#  |-- 212: string (nullable = true)
#  |-- 213: string (nullable = true)
#  |-- 214: string (nullable = true)
#  |-- 215: string (nullable = true)
#  |-- 216: string (nullable = true)
#  |-- 217: string (nullable = true)
#  |-- 218: string (nullable = true)
#  |-- 219: string (nullable = true)
#  |-- 22: string (nullable = true)
#  |-- 220: string (nullable = true)
#  |-- 221: string (nullable = true)
#  |-- 222: string (nullable = true)
#  |-- 223: string (nullable = true)
#  |-- 224: string (nullable = true)
#  |-- 225: string (nullable = true)
#  |-- 227: string (nullable = true)
#  |-- 228: string (nullable = true)
#  |-- 229: string (nullable = true)
#  |-- 23: string (nullable = true)
#  |-- 230: string (nullable = true)
#  |-- 231: string (nullable = true)
#  |-- 232: string (nullable = true)
#  |-- 233: string (nullable = true)
#  |-- 234: string (nullable = true)
#  |-- 235: string (nullable = true)
#  |-- 236: string (nullable = true)
#  |-- 237: string (nullable = true)
#  |-- 238: string (nullable = true)
#  |-- 239: string (nullable = true)
#  |-- 24: string (nullable = true)
#  |-- 240: string (nullable = true)
#  |-- 241: string (nullable = true)
#  |-- 242: string (nullable = true)
#  |-- 243: string (nullable = true)
#  |-- 244: string (nullable = true)
#  |-- 245: string (nullable = true)
#  |-- 246: string (nullable = true)
#  |-- 247: string (nullable = true)
#  |-- 248: string (nullable = true)
#  |-- 249: string (nullable = true)
#  |-- 25: string (nullable = true)
#  |-- 250: string (nullable = true)
#  |-- 251: string (nullable = true)
#  |-- 252: string (nullable = true)
#  |-- 253: string (nullable = true)
#  |-- 254: string (nullable = true)
#  |-- 255: string (nullable = true)
#  |-- 256: string (nullable = true)
#  |-- 257: string (nullable = true)
#  |-- 258: string (nullable = true)
#  |-- 259: string (nullable = true)
#  |-- 26: string (nullable = true)
#  |-- 260: string (nullable = true)
#  |-- 261: string (nullable = true)
#  |-- 262: string (nullable = true)
#  |-- 263: string (nullable = true)
#  |-- 264: string (nullable = true)
#  |-- 265: string (nullable = true)
#  |-- 266: string (nullable = true)
#  |-- 267: string (nullable = true)
#  |-- 268: string (nullable = true)
#  |-- 269: string (nullable = true)
#  |-- 27: string (nullable = true)
#  |-- 270: string (nullable = true)
#  |-- 271: string (nullable = true)
#  |-- 272: string (nullable = true)
#  |-- 273: string (nullable = true)
#  |-- 274: string (nullable = true)
#  |-- 275: string (nullable = true)
#  |-- 276: string (nullable = true)
#  |-- 277: string (nullable = true)
#  |-- 278: string (nullable = true)
#  |-- 279: string (nullable = true)
#  |-- 28: string (nullable = true)
#  |-- 280: string (nullable = true)
#  |-- 281: string (nullable = true)
#  |-- 282: string (nullable = true)
#  |-- 283: string (nullable = true)
#  |-- 284: string (nullable = true)
#  |-- 285: string (nullable = true)
#  |-- 286: string (nullable = true)
#  |-- 287: string (nullable = true)
#  |-- 288: string (nullable = true)
#  |-- 289: string (nullable = true)
#  |-- 29: string (nullable = true)
#  |-- 290: string (nullable = true)
#  |-- 291: string (nullable = true)
#  |-- 292: string (nullable = true)
#  |-- 293: string (nullable = true)
#  |-- 294: string (nullable = true)
#  |-- 295: string (nullable = true)
#  |-- 296: string (nullable = true)
#  |-- 297: string (nullable = true)
#  |-- 298: string (nullable = true)
#  |-- 299: string (nullable = true)
#  |-- 3: string (nullable = true)
#  |-- 30: string (nullable = true)
#  |-- 300: string (nullable = true)
#  |-- 301: string (nullable = true)
#  |-- 302: string (nullable = true)
#  |-- 303: string (nullable = true)
#  |-- 304: string (nullable = true)
#  |-- 305: string (nullable = true)
#  |-- 306: string (nullable = true)
#  |-- 307: string (nullable = true)
#  |-- 308: string (nullable = true)
#  |-- 309: string (nullable = true)
#  |-- 31: string (nullable = true)
#  |-- 310: string (nullable = true)
#  |-- 311: string (nullable = true)
#  |-- 312: string (nullable = true)
#  |-- 313: string (nullable = true)
#  |-- 314: string (nullable = true)
#  |-- 315: string (nullable = true)
#  |-- 316: string (nullable = true)
#  |-- 317: string (nullable = true)
#  |-- 318: string (nullable = true)
#  |-- 319: string (nullable = true)
#  |-- 32: string (nullable = true)
#  |-- 320: string (nullable = true)
#  |-- 321: string (nullable = true)
#  |-- 322: string (nullable = true)
#  |-- 323: string (nullable = true)
#  |-- 324: string (nullable = true)
#  |-- 325: string (nullable = true)
#  |-- 326: string (nullable = true)
#  |-- 327: string (nullable = true)
#  |-- 328: string (nullable = true)
#  |-- 329: string (nullable = true)
#  |-- 33: string (nullable = true)
#  |-- 330: string (nullable = true)
#  |-- 331: string (nullable = true)
#  |-- 332: string (nullable = true)
#  |-- 333: string (nullable = true)
#  |-- 334: string (nullable = true)
#  |-- 335: string (nullable = true)
#  |-- 336: string (nullable = true)
#  |-- 337: string (nullable = true)
#  |-- 338: string (nullable = true)
#  |-- 339: string (nullable = true)
#  |-- 34: string (nullable = true)
#  |-- 340: string (nullable = true)
#  |-- 341: string (nullable = true)
#  |-- 342: string (nullable = true)
#  |-- 343: string (nullable = true)
#  |-- 344: string (nullable = true)
#  |-- 345: string (nullable = true)
#  |-- 346: string (nullable = true)
#  |-- 347: string (nullable = true)
#  |-- 348: string (nullable = true)
#  |-- 349: string (nullable = true)
#  |-- 35: string (nullable = true)
#  |-- 350: string (nullable = true)
#  |-- 351: string (nullable = true)
#  |-- 352: string (nullable = true)
#  |-- 353: string (nullable = true)
#  |-- 354: string (nullable = true)
#  |-- 355: string (nullable = true)
#  |-- 356: string (nullable = true)
#  |-- 357: string (nullable = true)
#  |-- 358: string (nullable = true)
#  |-- 359: string (nullable = true)
#  |-- 36: string (nullable = true)
#  |-- 360: string (nullable = true)
#  |-- 361: string (nullable = true)
#  |-- 362: string (nullable = true)
#  |-- 363: string (nullable = true)
#  |-- 364: string (nullable = true)
#  |-- 365: string (nullable = true)
#  |-- 366: string (nullable = true)
#  |-- 367: string (nullable = true)
#  |-- 368: string (nullable = true)
#  |-- 369: string (nullable = true)
#  |-- 37: string (nullable = true)
#  |-- 370: string (nullable = true)
#  |-- 371: string (nullable = true)
#  |-- 372: string (nullable = true)
#  |-- 373: string (nullable = true)
#  |-- 374: string (nullable = true)
#  |-- 375: string (nullable = true)
#  |-- 376: string (nullable = true)
#  |-- 377: string (nullable = true)
#  |-- 378: string (nullable = true)
#  |-- 379: string (nullable = true)
#  |-- 38: string (nullable = true)
#  |-- 380: string (nullable = true)
#  |-- 381: string (nullable = true)
#  |-- 382: string (nullable = true)
#  |-- 383: string (nullable = true)
#  |-- 384: string (nullable = true)
#  |-- 385: string (nullable = true)
#  |-- 386: string (nullable = true)
#  |-- 387: string (nullable = true)
#  |-- 388: string (nullable = true)
#  |-- 389: string (nullable = true)
#  |-- 39: string (nullable = true)
#  |-- 390: string (nullable = true)
#  |-- 391: string (nullable = true)
#  |-- 392: string (nullable = true)
#  |-- 393: string (nullable = true)
#  |-- 394: string (nullable = true)
#  |-- 395: string (nullable = true)
#  |-- 396: string (nullable = true)
#  |-- 397: string (nullable = true)
#  |-- 398: string (nullable = true)
#  |-- 399: string (nullable = true)
#  |-- 4: string (nullable = true)
#  |-- 40: string (nullable = true)
#  |-- 400: string (nullable = true)
#  |-- 401: string (nullable = true)
#  |-- 402: string (nullable = true)
#  |-- 403: string (nullable = true)
#  |-- 404: string (nullable = true)
#  |-- 405: string (nullable = true)
#  |-- 406: string (nullable = true)
#  |-- 407: string (nullable = true)
#  |-- 408: string (nullable = true)
#  |-- 409: string (nullable = true)
#  |-- 41: string (nullable = true)
#  |-- 410: string (nullable = true)
#  |-- 411: string (nullable = true)
#  |-- 412: string (nullable = true)
#  |-- 413: string (nullable = true)
#  |-- 414: string (nullable = true)
#  |-- 415: string (nullable = true)
#  |-- 416: string (nullable = true)
#  |-- 417: string (nullable = true)
#  |-- 418: string (nullable = true)
#  |-- 419: string (nullable = true)
#  |-- 42: string (nullable = true)
#  |-- 420: string (nullable = true)
#  |-- 421: string (nullable = true)
#  |-- 422: string (nullable = true)
#  |-- 423: string (nullable = true)
#  |-- 424: string (nullable = true)
#  |-- 425: string (nullable = true)
#  |-- 426: string (nullable = true)
#  |-- 427: string (nullable = true)
#  |-- 428: string (nullable = true)
#  |-- 429: string (nullable = true)
#  |-- 43: string (nullable = true)
#  |-- 430: string (nullable = true)
#  |-- 431: string (nullable = true)
#  |-- 432: string (nullable = true)
#  |-- 433: string (nullable = true)
#  |-- 434: string (nullable = true)
#  |-- 435: string (nullable = true)
#  |-- 436: string (nullable = true)
#  |-- 437: string (nullable = true)
#  |-- 438: string (nullable = true)
#  |-- 439: string (nullable = true)
#  |-- 44: string (nullable = true)
#  |-- 440: string (nullable = true)
#  |-- 441: string (nullable = true)
#  |-- 442: string (nullable = true)
#  |-- 443: string (nullable = true)
#  |-- 444: string (nullable = true)
#  |-- 445: string (nullable = true)
#  |-- 446: string (nullable = true)
#  |-- 447: string (nullable = true)
#  |-- 448: string (nullable = true)
#  |-- 449: string (nullable = true)
#  |-- 45: string (nullable = true)
#  |-- 450: string (nullable = true)
#  |-- 451: string (nullable = true)
#  |-- 452: string (nullable = true)
#  |-- 453: string (nullable = true)
#  |-- 454: string (nullable = true)
#  |-- 455: string (nullable = true)
#  |-- 456: string (nullable = true)
#  |-- 457: string (nullable = true)
#  |-- 458: string (nullable = true)
#  |-- 459: string (nullable = true)
#  |-- 46: string (nullable = true)
#  |-- 460: string (nullable = true)
#  |-- 461: string (nullable = true)
#  |-- 462: string (nullable = true)
#  |-- 463: string (nullable = true)
#  |-- 464: string (nullable = true)
#  |-- 465: string (nullable = true)
#  |-- 466: string (nullable = true)
#  |-- 467: string (nullable = true)
#  |-- 468: string (nullable = true)
#  |-- 469: string (nullable = true)
#  |-- 47: string (nullable = true)
#  |-- 470: string (nullable = true)
#  |-- 471: string (nullable = true)
#  |-- 472: string (nullable = true)
#  |-- 473: string (nullable = true)
#  |-- 475: string (nullable = true)
#  |-- 476: string (nullable = true)
#  |-- 477: string (nullable = true)
#  |-- 478: string (nullable = true)
#  |-- 479: string (nullable = true)
#  |-- 48: string (nullable = true)
#  |-- 480: string (nullable = true)
#  |-- 481: string (nullable = true)
#  |-- 482: string (nullable = true)
#  |-- 483: string (nullable = true)
#  |-- 484: string (nullable = true)
#  |-- 485: string (nullable = true)
#  |-- 486: string (nullable = true)
#  |-- 487: string (nullable = true)
#  |-- 488: string (nullable = true)
#  |-- 489: string (nullable = true)
#  |-- 49: string (nullable = true)
#  |-- 490: string (nullable = true)
#  |-- 491: string (nullable = true)
#  |-- 492: string (nullable = true)
#  |-- 493: string (nullable = true)
#  |-- 494: string (nullable = true)
#  |-- 495: string (nullable = true)
#  |-- 496: string (nullable = true)
#  |-- 497: string (nullable = true)
#  |-- 498: string (nullable = true)
#  |-- 499: string (nullable = true)
#  |-- 5: string (nullable = true)
#  |-- 50: string (nullable = true)
#  |-- 500: string (nullable = true)
#  |-- 501: string (nullable = true)
#  |-- 502: string (nullable = true)
#  |-- 503: string (nullable = true)
#  |-- 504: string (nullable = true)
#  |-- 505: string (nullable = true)
#  |-- 506: string (nullable = true)
#  |-- 507: string (nullable = true)
#  |-- 508: string (nullable = true)
#  |-- 509: string (nullable = true)
#  |-- 51: string (nullable = true)
#  |-- 510: string (nullable = true)
#  |-- 511: string (nullable = true)
#  |-- 512: string (nullable = true)
#  |-- 513: string (nullable = true)
#  |-- 514: string (nullable = true)
#  |-- 515: string (nullable = true)
#  |-- 516: string (nullable = true)
#  |-- 517: string (nullable = true)
#  |-- 518: string (nullable = true)
#  |-- 519: string (nullable = true)
#  |-- 52: string (nullable = true)
#  |-- 520: string (nullable = true)
#  |-- 521: string (nullable = true)
#  |-- 522: string (nullable = true)
#  |-- 523: string (nullable = true)
#  |-- 524: string (nullable = true)
#  |-- 525: string (nullable = true)
#  |-- 526: string (nullable = true)
#  |-- 527: string (nullable = true)
#  |-- 528: string (nullable = true)
#  |-- 529: string (nullable = true)
#  |-- 53: string (nullable = true)
#  |-- 530: string (nullable = true)
#  |-- 531: string (nullable = true)
#  |-- 532: string (nullable = true)
#  |-- 533: string (nullable = true)
#  |-- 534: string (nullable = true)
#  |-- 535: string (nullable = true)
#  |-- 536: string (nullable = true)
#  |-- 537: string (nullable = true)
#  |-- 538: string (nullable = true)
#  |-- 539: string (nullable = true)
#  |-- 54: string (nullable = true)
#  |-- 540: string (nullable = true)
#  |-- 541: string (nullable = true)
#  |-- 542: string (nullable = true)
#  |-- 543: string (nullable = true)
#  |-- 544: string (nullable = true)
#  |-- 545: string (nullable = true)
#  |-- 546: string (nullable = true)
#  |-- 547: string (nullable = true)
#  |-- 548: string (nullable = true)
#  |-- 549: string (nullable = true)
#  |-- 55: string (nullable = true)
#  |-- 550: string (nullable = true)
#  |-- 551: string (nullable = true)
#  |-- 552: string (nullable = true)
#  |-- 553: string (nullable = true)
#  |-- 554: string (nullable = true)
#  |-- 555: string (nullable = true)
#  |-- 556: string (nullable = true)
#  |-- 557: string (nullable = true)
#  |-- 558: string (nullable = true)
#  |-- 559: string (nullable = true)
#  |-- 56: string (nullable = true)
#  |-- 560: string (nullable = true)
#  |-- 561: string (nullable = true)
#  |-- 562: string (nullable = true)
#  |-- 563: string (nullable = true)
#  |-- 564: string (nullable = true)
#  |-- 565: string (nullable = true)
#  |-- 566: string (nullable = true)
#  |-- 567: string (nullable = true)
#  |-- 568: string (nullable = true)
#  |-- 569: string (nullable = true)
#  |-- 57: string (nullable = true)
#  |-- 570: string (nullable = true)
#  |-- 571: string (nullable = true)
#  |-- 572: string (nullable = true)
#  |-- 573: string (nullable = true)
#  |-- 574: string (nullable = true)
#  |-- 575: string (nullable = true)
#  |-- 576: string (nullable = true)
#  |-- 577: string (nullable = true)
#  |-- 578: string (nullable = true)
#  |-- 579: string (nullable = true)
#  |-- 58: string (nullable = true)
#  |-- 580: string (nullable = true)
#  |-- 581: string (nullable = true)
#  |-- 582: string (nullable = true)
#  |-- 583: string (nullable = true)
#  |-- 584: string (nullable = true)
#  |-- 585: string (nullable = true)
#  |-- 586: string (nullable = true)
#  |-- 587: string (nullable = true)
#  |-- 588: string (nullable = true)
#  |-- 589: string (nullable = true)
#  |-- 59: string (nullable = true)
#  |-- 590: string (nullable = true)
#  |-- 591: string (nullable = true)
#  |-- 592: string (nullable = true)
#  |-- 593: string (nullable = true)
#  |-- 594: string (nullable = true)
#  |-- 595: string (nullable = true)
#  |-- 596: string (nullable = true)
#  |-- 597: string (nullable = true)
#  |-- 598: string (nullable = true)
#  |-- 599: string (nullable = true)
#  |-- 6: string (nullable = true)
#  |-- 60: string (nullable = true)
#  |-- 600: string (nullable = true)
#  |-- 601: string (nullable = true)
#  |-- 602: string (nullable = true)
#  |-- 603: string (nullable = true)
#  |-- 604: string (nullable = true)
#  |-- 605: string (nullable = true)
#  |-- 606: string (nullable = true)
#  |-- 607: string (nullable = true)
#  |-- 608: string (nullable = true)
#  |-- 609: string (nullable = true)
#  |-- 61: string (nullable = true)
#  |-- 610: string (nullable = true)
#  |-- 611: string (nullable = true)
#  |-- 612: string (nullable = true)
#  |-- 613: string (nullable = true)
#  |-- 614: string (nullable = true)
#  |-- 615: string (nullable = true)
#  |-- 616: string (nullable = true)
#  |-- 617: string (nullable = true)
#  |-- 618: string (nullable = true)
#  |-- 619: string (nullable = true)
#  |-- 62: string (nullable = true)
#  |-- 620: string (nullable = true)
#  |-- 621: string (nullable = true)
#  |-- 622: string (nullable = true)
#  |-- 623: string (nullable = true)
#  |-- 624: string (nullable = true)
#  |-- 625: string (nullable = true)
#  |-- 626: string (nullable = true)
#  |-- 627: string (nullable = true)
#  |-- 628: string (nullable = true)
#  |-- 629: string (nullable = true)
#  |-- 63: string (nullable = true)
#  |-- 630: string (nullable = true)
#  |-- 631: string (nullable = true)
#  |-- 632: string (nullable = true)
#  |-- 633: string (nullable = true)
#  |-- 634: string (nullable = true)
#  |-- 635: string (nullable = true)
#  |-- 636: string (nullable = true)
#  |-- 637: string (nullable = true)
#  |-- 638: string (nullable = true)
#  |-- 639: string (nullable = true)
#  |-- 64: string (nullable = true)
#  |-- 640: string (nullable = true)
#  |-- 641: string (nullable = true)
#  |-- 642: string (nullable = true)
#  |-- 643: string (nullable = true)
#  |-- 644: string (nullable = true)
#  |-- 645: string (nullable = true)
#  |-- 646: string (nullable = true)
#  |-- 647: string (nullable = true)
#  |-- 648: string (nullable = true)
#  |-- 649: string (nullable = true)
#  |-- 65: string (nullable = true)
#  |-- 650: string (nullable = true)
#  |-- 651: string (nullable = true)
#  |-- 652: string (nullable = true)
#  |-- 653: string (nullable = true)
#  |-- 654: string (nullable = true)
#  |-- 655: string (nullable = true)
#  |-- 656: string (nullable = true)
#  |-- 657: string (nullable = true)
#  |-- 658: string (nullable = true)
#  |-- 659: string (nullable = true)
#  |-- 66: string (nullable = true)
#  |-- 660: string (nullable = true)
#  |-- 661: string (nullable = true)
#  |-- 662: string (nullable = true)
#  |-- 663: string (nullable = true)
#  |-- 664: string (nullable = true)
#  |-- 665: string (nullable = true)
#  |-- 666: string (nullable = true)
#  |-- 667: string (nullable = true)
#  |-- 668: string (nullable = true)
#  |-- 669: string (nullable = true)
#  |-- 67: string (nullable = true)
#  |-- 670: string (nullable = true)
#  |-- 671: string (nullable = true)
#  |-- 672: string (nullable = true)
#  |-- 673: string (nullable = true)
#  |-- 674: string (nullable = true)
#  |-- 675: string (nullable = true)
#  |-- 676: string (nullable = true)
#  |-- 677: string (nullable = true)
#  |-- 678: string (nullable = true)
#  |-- 679: string (nullable = true)
#  |-- 68: string (nullable = true)
#  |-- 680: string (nullable = true)
#  |-- 681: string (nullable = true)
#  |-- 682: string (nullable = true)
#  |-- 683: string (nullable = true)
#  |-- 684: string (nullable = true)
#  |-- 685: string (nullable = true)
#  |-- 686: string (nullable = true)
#  |-- 687: string (nullable = true)
#  |-- 688: string (nullable = true)
#  |-- 689: string (nullable = true)
#  |-- 69: string (nullable = true)
#  |-- 690: string (nullable = true)
#  |-- 691: string (nullable = true)
#  |-- 692: string (nullable = true)
#  |-- 693: string (nullable = true)
#  |-- 694: string (nullable = true)
#  |-- 695: string (nullable = true)
#  |-- 696: string (nullable = true)
#  |-- 697: string (nullable = true)
#  |-- 698: string (nullable = true)
#  |-- 699: string (nullable = true)
#  |-- 7: string (nullable = true)
#  |-- 70: string (nullable = true)
#  |-- 700: string (nullable = true)
#  |-- 701: string (nullable = true)
#  |-- 702: string (nullable = true)
#  |-- 703: string (nullable = true)
#  |-- 704: string (nullable = true)
#  |-- 705: string (nullable = true)
#  |-- 706: string (nullable = true)
#  |-- 707: string (nullable = true)
#  |-- 708: string (nullable = true)
#  |-- 709: string (nullable = true)
#  |-- 71: string (nullable = true)
#  |-- 710: string (nullable = true)
#  |-- 711: string (nullable = true)
#  |-- 712: string (nullable = true)
#  |-- 713: string (nullable = true)
#  |-- 714: string (nullable = true)
#  |-- 715: string (nullable = true)
#  |-- 716: string (nullable = true)
#  |-- 717: string (nullable = true)
#  |-- 718: string (nullable = true)
#  |-- 719: string (nullable = true)
#  |-- 72: string (nullable = true)
#  |-- 720: string (nullable = true)
#  |-- 721: string (nullable = true)
#  |-- 722: string (nullable = true)
#  |-- 723: string (nullable = true)
#  |-- 724: string (nullable = true)
#  |-- 725: string (nullable = true)
#  |-- 726: string (nullable = true)
#  |-- 727: string (nullable = true)
#  |-- 728: string (nullable = true)
#  |-- 729: string (nullable = true)
#  |-- 73: string (nullable = true)
#  |-- 730: string (nullable = true)
#  |-- 731: string (nullable = true)
#  |-- 732: string (nullable = true)
#  |-- 733: string (nullable = true)
#  |-- 734: string (nullable = true)
#  |-- 735: string (nullable = true)
#  |-- 736: string (nullable = true)
#  |-- 737: string (nullable = true)
#  |-- 738: string (nullable = true)
#  |-- 739: string (nullable = true)
#  |-- 74: string (nullable = true)
#  |-- 740: string (nullable = true)
#  |-- 741: string (nullable = true)
#  |-- 742: string (nullable = true)
#  |-- 743: string (nullable = true)
#  |-- 744: string (nullable = true)
#  |-- 745: string (nullable = true)
#  |-- 746: string (nullable = true)
#  |-- 747: string (nullable = true)
#  |-- 748: string (nullable = true)
#  |-- 749: string (nullable = true)
#  |-- 75: string (nullable = true)
#  |-- 750: string (nullable = true)
#  |-- 751: string (nullable = true)
#  |-- 752: string (nullable = true)
#  |-- 753: string (nullable = true)
#  |-- 754: string (nullable = true)
#  |-- 755: string (nullable = true)
#  |-- 756: string (nullable = true)
#  |-- 757: string (nullable = true)
#  |-- 758: string (nullable = true)
#  |-- 759: string (nullable = true)
#  |-- 76: string (nullable = true)
#  |-- 760: string (nullable = true)
#  |-- 761: string (nullable = true)
#  |-- 762: string (nullable = true)
#  |-- 763: string (nullable = true)
#  |-- 764: string (nullable = true)
#  |-- 765: string (nullable = true)
#  |-- 766: string (nullable = true)
#  |-- 767: string (nullable = true)
#  |-- 768: string (nullable = true)
#  |-- 769: string (nullable = true)
#  |-- 77: string (nullable = true)
#  |-- 770: string (nullable = true)
#  |-- 771: string (nullable = true)
#  |-- 772: string (nullable = true)
#  |-- 773: string (nullable = true)
#  |-- 774: string (nullable = true)
#  |-- 775: string (nullable = true)
#  |-- 776: string (nullable = true)
#  |-- 777: string (nullable = true)
#  |-- 778: string (nullable = true)
#  |-- 779: string (nullable = true)
#  |-- 78: string (nullable = true)
#  |-- 780: string (nullable = true)
#  |-- 781: string (nullable = true)
#  |-- 782: string (nullable = true)
#  |-- 783: string (nullable = true)
#  |-- 784: string (nullable = true)
#  |-- 785: string (nullable = true)
#  |-- 786: string (nullable = true)
#  |-- 787: string (nullable = true)
#  |-- 788: string (nullable = true)
#  |-- 789: string (nullable = true)
#  |-- 79: string (nullable = true)
#  |-- 790: string (nullable = true)
#  |-- 791: string (nullable = true)
#  |-- 792: string (nullable = true)
#  |-- 793: string (nullable = true)
#  |-- 794: string (nullable = true)
#  |-- 795: string (nullable = true)
#  |-- 796: string (nullable = true)
#  |-- 797: string (nullable = true)
#  |-- 798: string (nullable = true)
#  |-- 799: string (nullable = true)
#  |-- 8: string (nullable = true)
#  |-- 80: string (nullable = true)
#  |-- 800: string (nullable = true)
#  |-- 801: string (nullable = true)
#  |-- 802: string (nullable = true)
#  |-- 803: string (nullable = true)
#  |-- 804: string (nullable = true)
#  |-- 805: string (nullable = true)
#  |-- 806: string (nullable = true)
#  |-- 807: string (nullable = true)
#  |-- 808: string (nullable = true)
#  |-- 809: string (nullable = true)
#  |-- 81: string (nullable = true)
#  |-- 810: string (nullable = true)
#  |-- 811: string (nullable = true)
#  |-- 812: string (nullable = true)
#  |-- 813: string (nullable = true)
#  |-- 814: string (nullable = true)
#  |-- 815: string (nullable = true)
#  |-- 816: string (nullable = true)
#  |-- 817: string (nullable = true)
#  |-- 818: string (nullable = true)
#  |-- 819: string (nullable = true)
#  |-- 82: string (nullable = true)
#  |-- 820: string (nullable = true)
#  |-- 821: string (nullable = true)
#  |-- 822: string (nullable = true)
#  |-- 823: string (nullable = true)
#  |-- 824: string (nullable = true)
#  |-- 825: string (nullable = true)
#  |-- 826: string (nullable = true)
#  |-- 827: string (nullable = true)
#  |-- 828: string (nullable = true)
#  |-- 829: string (nullable = true)
#  |-- 83: string (nullable = true)
#  |-- 830: string (nullable = true)
#  |-- 831: string (nullable = true)
#  |-- 832: string (nullable = true)
#  |-- 833: string (nullable = true)
#  |-- 834: string (nullable = true)
#  |-- 835: string (nullable = true)
#  |-- 836: string (nullable = true)
#  |-- 837: string (nullable = true)
#  |-- 838: string (nullable = true)
#  |-- 839: string (nullable = true)
#  |-- 84: string (nullable = true)
#  |-- 840: string (nullable = true)
#  |-- 841: string (nullable = true)
#  |-- 842: string (nullable = true)
#  |-- 843: string (nullable = true)
#  |-- 844: string (nullable = true)
#  |-- 845: string (nullable = true)
#  |-- 846: string (nullable = true)
#  |-- 847: string (nullable = true)
#  |-- 848: string (nullable = true)
#  |-- 849: string (nullable = true)
#  |-- 85: string (nullable = true)
#  |-- 850: string (nullable = true)
#  |-- 851: string (nullable = true)
#  |-- 852: string (nullable = true)
#  |-- 853: string (nullable = true)
#  |-- 854: string (nullable = true)
#  |-- 855: string (nullable = true)
#  |-- 856: string (nullable = true)
#  |-- 857: string (nullable = true)
#  |-- 858: string (nullable = true)
#  |-- 859: string (nullable = true)
#  |-- 86: string (nullable = true)
#  |-- 860: string (nullable = true)
#  |-- 861: string (nullable = true)
#  |-- 862: string (nullable = true)
#  |-- 863: string (nullable = true)
#  |-- 864: string (nullable = true)
#  |-- 865: string (nullable = true)
#  |-- 866: string (nullable = true)
#  |-- 867: string (nullable = true)
#  |-- 868: string (nullable = true)
#  |-- 869: string (nullable = true)
#  |-- 87: string (nullable = true)
#  |-- 870: string (nullable = true)
#  |-- 871: string (nullable = true)
#  |-- 872: string (nullable = true)
#  |-- 873: string (nullable = true)
#  |-- 874: string (nullable = true)
#  |-- 875: string (nullable = true)
#  |-- 876: string (nullable = true)
#  |-- 877: string (nullable = true)
#  |-- 878: string (nullable = true)
#  |-- 879: string (nullable = true)
#  |-- 88: string (nullable = true)
#  |-- 880: string (nullable = true)
#  |-- 881: string (nullable = true)
#  |-- 882: string (nullable = true)
#  |-- 883: string (nullable = true)
#  |-- 884: string (nullable = true)
#  |-- 885: string (nullable = true)
#  |-- 886: string (nullable = true)
#  |-- 887: string (nullable = true)
#  |-- 888: string (nullable = true)
#  |-- 889: string (nullable = true)
#  |-- 89: string (nullable = true)
#  |-- 890: string (nullable = true)
#  |-- 891: string (nullable = true)
#  |-- 892: string (nullable = true)
#  |-- 893: string (nullable = true)
#  |-- 894: string (nullable = true)
#  |-- 895: string (nullable = true)
#  |-- 896: string (nullable = true)
#  |-- 897: string (nullable = true)
#  |-- 898: string (nullable = true)
#  |-- 899: string (nullable = true)
#  |-- 9: string (nullable = true)
#  |-- 90: string (nullable = true)
#  |-- 900: string (nullable = true)
#  |-- 901: string (nullable = true)
#  |-- 902: string (nullable = true)
#  |-- 903: string (nullable = true)
#  |-- 904: string (nullable = true)
#  |-- 905: string (nullable = true)
#  |-- 906: string (nullable = true)
#  |-- 907: string (nullable = true)
#  |-- 908: string (nullable = true)
#  |-- 909: string (nullable = true)
#  |-- 91: string (nullable = true)
#  |-- 910: string (nullable = true)
#  |-- 911: string (nullable = true)
#  |-- 912: string (nullable = true)
#  |-- 913: string (nullable = true)
#  |-- 914: string (nullable = true)
#  |-- 915: string (nullable = true)
#  |-- 916: string (nullable = true)
#  |-- 917: string (nullable = true)
#  |-- 918: string (nullable = true)
#  |-- 919: string (nullable = true)
#  |-- 92: string (nullable = true)
#  |-- 920: string (nullable = true)
#  |-- 921: string (nullable = true)
#  |-- 922: string (nullable = true)
#  |-- 923: string (nullable = true)
#  |-- 924: string (nullable = true)
#  |-- 925: string (nullable = true)
#  |-- 926: string (nullable = true)
#  |-- 927: string (nullable = true)
#  |-- 928: string (nullable = true)
#  |-- 929: string (nullable = true)
#  |-- 93: string (nullable = true)
#  |-- 930: string (nullable = true)
#  |-- 931: string (nullable = true)
#  |-- 932: string (nullable = true)
#  |-- 933: string (nullable = true)
#  |-- 934: string (nullable = true)
#  |-- 935: string (nullable = true)
#  |-- 936: string (nullable = true)
#  |-- 937: string (nullable = true)
#  |-- 938: string (nullable = true)
#  |-- 939: string (nullable = true)
#  |-- 94: string (nullable = true)
#  |-- 940: string (nullable = true)
#  |-- 941: string (nullable = true)
#  |-- 942: string (nullable = true)
#  |-- 943: string (nullable = true)
#  |-- 944: string (nullable = true)
#  |-- 945: string (nullable = true)
#  |-- 947: string (nullable = true)
#  |-- 948: string (nullable = true)
#  |-- 949: string (nullable = true)
#  |-- 95: string (nullable = true)
#  |-- 950: string (nullable = true)
#  |-- 951: string (nullable = true)
#  |-- 952: string (nullable = true)
#  |-- 953: string (nullable = true)
#  |-- 954: string (nullable = true)
#  |-- 955: string (nullable = true)
#  |-- 956: string (nullable = true)
#  |-- 957: string (nullable = true)
#  |-- 958: string (nullable = true)
#  |-- 959: string (nullable = true)
#  |-- 96: string (nullable = true)
#  |-- 960: string (nullable = true)
#  |-- 961: string (nullable = true)
#  |-- 962: string (nullable = true)
#  |-- 963: string (nullable = true)
#  |-- 964: string (nullable = true)
#  |-- 965: string (nullable = true)
#  |-- 966: string (nullable = true)
#  |-- 967: string (nullable = true)
#  |-- 968: string (nullable = true)
#  |-- 969: string (nullable = true)
#  |-- 97: string (nullable = true)
#  |-- 970: string (nullable = true)
#  |-- 971: string (nullable = true)
#  |-- 972: string (nullable = true)
#  |-- 973: string (nullable = true)
#  |-- 974: string (nullable = true)
#  |-- 975: string (nullable = true)
#  |-- 976: string (nullable = true)
#  |-- 977: string (nullable = true)
#  |-- 978: string (nullable = true)
#  |-- 979: string (nullable = true)
#  |-- 98: string (nullable = true)
#  |-- 980: string (nullable = true)
#  |-- 981: string (nullable = true)
#  |-- 982: string (nullable = true)
#  |-- 983: string (nullable = true)
#  |-- 984: string (nullable = true)
#  |-- 985: string (nullable = true)
#  |-- 986: string (nullable = true)
#  |-- 987: string (nullable = true)
#  |-- 988: string (nullable = true)
#  |-- 989: string (nullable = true)
#  |-- 99: string (nullable = true)
#  |-- 990: string (nullable = true)
#  |-- 991: string (nullable = true)
#  |-- 992: string (nullable = true)
#  |-- 993: string (nullable = true)
#  |-- 994: string (nullable = true)
#  |-- 995: string (nullable = true)
#  |-- 996: string (nullable = true)
#  |-- 997: string (nullable = true)
#  |-- 998: string (nullable = true)
#  |-- 999: string (nullable = true)
#  |-- available: string (nullable = true)
#  |-- categoryid: string (nullable = true)

# %%
dim_items_df.write.mode("overwrite") \
    .parquet("file:///home/talentum/test-jupyter/ecommerce-clickstream-etl/data/processed/dim_items")

# %%
category_df = spark.read \
    .option("header", "true") \
    .csv("file:///home/talentum/test-jupyter/ecommerce-clickstream-etl/data/raw/category_tree.csv")

category_df.printSchema()
category_df.show(5)
# Out:
# root
#  |-- categoryid: string (nullable = true)
#  |-- parentid: string (nullable = true)
#
# +----------+--------+
# |categoryid|parentid|
# +----------+--------+
# |      1016|     213|
# |       809|     169|
# |       570|       9|
# |      1691|     885|
# |       536|    1691|
# +----------+--------+
# only showing top 5 rows

# %%
category_df.write.mode("overwrite") \
    .parquet("file:///home/talentum/test-jupyter/ecommerce-clickstream-etl/data/processed/dim_category")
